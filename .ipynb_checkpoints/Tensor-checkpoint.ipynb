# %%
import tensorflow as tf

# Create constants (tensors)
a = tf.constant(2)
b = tf.constant(3)

# Perform operations
sum = tf.add(a, b)
product = tf.multiply(a, b)

print("Sum:", sum.numpy())  # Output the sum
print("Product:", product.numpy())  # Output the product
# Out:
# Sum: 5
# Product: 6

# %%
from tensorflow.keras.datasets import mnist

# Load the dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the images
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
from tensorflow.keras import models, layers

# Build the model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the 2D images into 1D vectors
    layers.Dense(128, activation='relu'),  # First dense layer with 128 neurons
    layers.Dense(10, activation='softmax')  # Output layer with 10 neurons for 10 classes
])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras import models, layers

# Use Input to define the input shape explicitly
model = models.Sequential([
    layers.Input(shape=(28, 28)),  # No warning
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 769us/step - accuracy: 0.8795 - loss: 0.4207
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step - accuracy: 0.9640 - loss: 0.1211
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.9760 - loss: 0.0799
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 769us/step - accuracy: 0.9813 - loss: 0.0607
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step - accuracy: 0.9870 - loss: 0.0436

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - accuracy: 0.9741 - loss: 0.0883
# Test accuracy: 0.977400004863739

# %%
# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9890 - loss: 0.0348 - val_accuracy: 0.9792 - val_loss: 0.0683
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9921 - loss: 0.0270 - val_accuracy: 0.9794 - val_loss: 0.0737
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9940 - loss: 0.0194 - val_accuracy: 0.9783 - val_loss: 0.0741
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9944 - loss: 0.0176 - val_accuracy: 0.9780 - val_loss: 0.0743
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9958 - loss: 0.0142 - val_accuracy: 0.9784 - val_loss: 0.0786

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc}")
print(f"Test loss: {test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - accuracy: 0.9748 - loss: 0.0925
# Test accuracy: 0.9783999919891357
# Test loss: 0.07864715903997421

# %%
# Making predictions on the test set
predictions = model.predict(x_test)

# Output the prediction for the first test sample
print(predictions[0])  # Returns the probabilities for each class (0-9 for MNIST)

# Get the predicted class with the highest probability
predicted_class = tf.argmax(predictions[0])

print(f"Predicted class: {predicted_class}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step
# [1.1764590e-09 9.6991609e-11 3.5358301e-09 8.5440632e-08 1.0654292e-14
#  1.8137293e-10 4.1032106e-15 9.9999988e-01 1.9245867e-10 9.4627159e-09]
# Predicted class: 7

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.datasets import mnist

# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build model
model = models.Sequential([
    layers.Input(shape=(28, 28)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
print(f"Test loss: {test_loss}")

# Make predictions
predictions = model.predict(x_test)
predicted_class = tf.argmax(predictions[0])
print(f"Predicted class for first test image: {predicted_class}")
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 882us/step - accuracy: 0.8767 - loss: 0.4351 - val_accuracy: 0.9616 - val_loss: 0.1333
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 842us/step - accuracy: 0.9623 - loss: 0.1246 - val_accuracy: 0.9700 - val_loss: 0.0991
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 834us/step - accuracy: 0.9757 - loss: 0.0825 - val_accuracy: 0.9749 - val_loss: 0.0804
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9820 - loss: 0.0584 - val_accuracy: 0.9759 - val_loss: 0.0756
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 842us/step - accuracy: 0.9863 - loss: 0.0439 - val_accuracy: 0.9773 - val_loss: 0.0762
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - accuracy: 0.9742 - loss: 0.0878
# Test accuracy: 0.9772999882698059
# Test loss: 0.07620210200548172
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
# Predicted class for first test image: 7

# %%
import matplotlib.pyplot as plt

# Train the model and save the training history
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9969 - loss: 0.0107 - val_accuracy: 0.9783 - val_loss: 0.0820
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9973 - loss: 0.0094 - val_accuracy: 0.9783 - val_loss: 0.0818
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9973 - loss: 0.0093 - val_accuracy: 0.9799 - val_loss: 0.0778
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9982 - loss: 0.0069 - val_accuracy: 0.9771 - val_loss: 0.0891
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9983 - loss: 0.0060 - val_accuracy: 0.9786 - val_loss: 0.0937

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Load dataset (MNIST: images of handwritten digits 0-9)
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize data (scaling pixel values to between 0 and 1)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build the model (a simple neural network)
model = models.Sequential([
    layers.Input(shape=(28, 28)),        # Input layer to specify the shape of the images (28x28 pixels)
    layers.Flatten(),                    # Flatten the 28x28 pixel grid into a 1D array
    layers.Dense(128, activation='relu'), # First Dense layer with 128 neurons, using ReLU activation
    layers.Dense(10, activation='softmax') # Output layer with 10 neurons (one for each digit) using softmax activation
])

# Compile the model (configure the learning process)
model.compile(optimizer='adam',                          # Adam optimizer for adjusting weights
              loss='sparse_categorical_crossentropy',     # Loss function to measure error
              metrics=['accuracy'])                      # Track accuracy as the performance metric

# Train the model on the training data and validate on the test data
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))

# Plot training & validation accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss over epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Make predictions on the test data
predictions = model.predict(x_test)

# Select random test samples and visualize predictions vs actual labels
num_images = 5
random_idx = np.random.choice(x_test.shape[0], num_images)

for i, idx in enumerate(random_idx):
    plt.imshow(x_test[idx], cmap='gray')    # Show the test image
    plt.title(f"Predicted: {np.argmax(predictions[idx])}, True: {y_test[idx]}")  # Display the predicted vs actual label
    plt.axis('off')  # Hide the axes for better display
    plt.show()

# Compute the confusion matrix (comparison of predictions vs actual labels)
y_pred = np.argmax(predictions, axis=1)
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8786 - loss: 0.4257 - val_accuracy: 0.9541 - val_loss: 0.1459
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9647 - loss: 0.1219 - val_accuracy: 0.9707 - val_loss: 0.1009
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 985us/step - accuracy: 0.9770 - loss: 0.0776 - val_accuracy: 0.9733 - val_loss: 0.0874
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 985us/step - accuracy: 0.9824 - loss: 0.0573 - val_accuracy: 0.9751 - val_loss: 0.0797
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 991us/step - accuracy: 0.9867 - loss: 0.0430 - val_accuracy: 0.9779 - val_loss: 0.0747
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
